# %% [markdown]
# Group33 Wrokbook
# Group Member: Max Zhang, William Xu

# %%
import pandas as pd
import numpy as np

# %%
f1data=pd.read_csv("data/f1_race_results_2010_2023.csv")
f1data.head()
# Out:
#    season  round           race_name                        circuit  \
# 0    2010      1  Bahrain Grand Prix  Bahrain International Circuit
# 1    2010      1  Bahrain Grand Prix  Bahrain International Circuit
# 2    2010      1  Bahrain Grand Prix  Bahrain International Circuit
# 3    2010      1  Bahrain Grand Prix  Bahrain International Circuit
# 4    2010      1  Bahrain Grand Prix  Bahrain International Circuit
#
#          date driver_id  driver_number       driver_name constructor  grid  \
# 0  2010-03-14    alonso              8   Fernando Alonso     Ferrari     3
# 1  2010-03-14     massa              7      Felipe Massa     Ferrari     2
# 2  2010-03-14  hamilton              2    Lewis Hamilton     McLaren     4
# 3  2010-03-14    vettel              5  Sebastian Vettel    Red Bull     1
# 4  2010-03-14   rosberg              4      Nico Rosberg    Mercedes     5
#
#    position position_text    status  laps         time  fastest_lap_rank  \
# 0         1             1  Finished    49  1:39:20.396               1.0
# 1         2             2  Finished    49      +16.099               5.0
# 2         3             3  Finished    49      +23.182               4.0
# 3         4             4  Finished    49      +38.799              12.0
# 4         5             5  Finished    49      +40.213              13.0
#
#   fastest_lap_time
# 0         1:58.287
# 1         1:59.732
# 2         1:59.560
# 3         2:00.218
# 4         2:00.236

# %%
f1data['time'].describe()
# Out:
# count        3022
# unique       2997
# top       +13.842
# freq            2
# Name: time, dtype: object
